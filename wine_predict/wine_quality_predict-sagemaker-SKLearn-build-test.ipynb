# %% [markdown]
# This notebook was modified from the DSBA-6190 Project 2 notebook to incorporate use of Amazon Sagemaker.
#
# The Wine Quality Dataset (https://archive.ics.uci.edu/ml/datasets/Wine+Quality) was used as the data input. Several regression models were generated, using the provided data to predict red wine quality.

# %% [markdown]
# # Import

# %% [markdown]
# ## Libraries / Packages

# %%
# General
import pandas as pd
import numpy as np

import os
import tarfile
import datetime

#SageMaker
import boto3
import io
import sagemaker
from sagemaker import get_execution_role
from sagemaker.sklearn.processing import SKLearnProcessor
from sagemaker.processing import ProcessingInput, ProcessingOutput
from sagemaker.sklearn.estimator import SKLearn
from sagemaker.tuner import IntegerParameter, CategoricalParameter

# Data Preparation
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Modeling
from sklearn.ensemble import RandomForestRegressor

# Output
from sklearn.metrics import mean_squared_error,r2_score

# Export
from sklearn.externals import joblib

seed = 5590

# %% [markdown]
# ## Sagemaker Settings

# %%
region = boto3.session.Session().region_name
print('Region: {}'.format(region))

#role = get_execution_role()
role = 'arn:aws:iam::726963482731:role/service-role/AmazonSageMaker-ExecutionRole-20200222T172260'
print('Role: {}'.format(role))

sm_boto3 = boto3.client('sagemaker')
print(sm_boto3)
# Out:
# Region: us-east-1
# Role: arn:aws:iam::726963482731:role/service-role/AmazonSageMaker-ExecutionRole-20200222T172260
# <botocore.client.SageMaker object at 0x7f151af4dcc0>

# %% [markdown]
# ## Data

# %% [markdown]
# Initialize the S3 connection and name the target bucket.

# %%
'''
s3_client = boto3.client('s3')
data_bucket_name='dsba-6190-final-team-project'
'''

# %% [markdown]
# Check the contents of the bucket, and assign the import data file path and name to the variable **file_data**.

# %%
'''
obj_list=s3_client.list_objects(Bucket=data_bucket_name)
'''

# %%
'''
obj_list['Contents']
'''
# Out:
# [{'Key': 'build-test/',
#   'LastModified': datetime.datetime(2020, 3, 2, 21, 2, 14, tzinfo=tzlocal()),
#   'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#   'Size': 0,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'data/',
#   'LastModified': datetime.datetime(2020, 2, 22, 22, 44, 56, tzinfo=tzlocal()),
#   'ETag': '"d41d8cd98f00b204e9800998ecf8427e"',
#   'Size': 0,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'data/winequality-red.csv',
#   'LastModified': datetime.datetime(2020, 2, 22, 22, 45, 57, tzinfo=tzlocal()),
#   'ETag': '"2daeecee174368f8a33b82c8cccae3a5"',
#   'Size': 84199,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'driver_imgs_list.csv',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 1, tzinfo=tzlocal()),
#   'ETag': '"a4640e8465d32fa54358c06cb642ca87"',
#   'Size': 491359,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_1.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 3, tzinfo=tzlocal()),
#   'ETag': '"f87f22b332c6424414fe3e739a0cf413"',
#   'Size': 41638,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 3, tzinfo=tzlocal()),
#   'ETag': '"720c75c9821534cdd2b3f92d885cea7c"',
#   'Size': 37882,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 3, tzinfo=tzlocal()),
#   'ETag': '"5d6138506d0539d816736a839be72a0d"',
#   'Size': 49404,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_1000.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 3, tzinfo=tzlocal()),
#   'ETag': '"7153b4eed5f56121df15a2d6de50a33c"',
#   'Size': 40615,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100000.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 3, tzinfo=tzlocal()),
#   'ETag': '"ccdfe868b04d53790a7b9996a3f3422e"',
#   'Size': 38247,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100001.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 3, tzinfo=tzlocal()),
#   'ETag': '"030ae3f83eec828a3fb52bdfe9b949ca"',
#   'Size': 42526,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100002.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 3, tzinfo=tzlocal()),
#   'ETag': '"244bc8ab9868d6bed9e6937be86b6191"',
#   'Size': 44274,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100003.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 3, tzinfo=tzlocal()),
#   'ETag': '"e29f28369776ac9165310ddaaf4776f4"',
#   'Size': 48805,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100004.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 3, tzinfo=tzlocal()),
#   'ETag': '"08f467cb290291577c4ddc85eed3dbba"',
#   'Size': 37891,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100005.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 3, tzinfo=tzlocal()),
#   'ETag': '"acfc6fd3cb0e720aed87217a879531c8"',
#   'Size': 42303,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100007.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 3, tzinfo=tzlocal()),
#   'ETag': '"9b12edf288db0b99acd645e53ee37e84"',
#   'Size': 38847,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100008.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 3, tzinfo=tzlocal()),
#   'ETag': '"c2f9a83a558d8a2a2062f0a743dd9e3f"',
#   'Size': 48678,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100009.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 3, tzinfo=tzlocal()),
#   'ETag': '"f4e55b1d422466f349eff31ff36f02c8"',
#   'Size': 42355,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10001.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 3, tzinfo=tzlocal()),
#   'ETag': '"218af94ed9f2367552e0866bdfa09ffb"',
#   'Size': 39447,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100010.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 3, tzinfo=tzlocal()),
#   'ETag': '"b99a820a90812621b9b18e4a38952490"',
#   'Size': 45723,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100011.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 3, tzinfo=tzlocal()),
#   'ETag': '"97c1bfb6854bd3d220f7a1c69c5d9331"',
#   'Size': 39139,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100012.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 3, tzinfo=tzlocal()),
#   'ETag': '"109c8dcf9093a9ac4b35e6896f1dabb9"',
#   'Size': 46822,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100013.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 3, tzinfo=tzlocal()),
#   'ETag': '"4f737e4b1057407f0df66c3e9f88cbd3"',
#   'Size': 35174,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100014.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 3, tzinfo=tzlocal()),
#   'ETag': '"1a72de14ca0ccecedaa6c07ccff0f2d8"',
#   'Size': 42614,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100016.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 3, tzinfo=tzlocal()),
#   'ETag': '"7011329885970ea747c3d4e373371d34"',
#   'Size': 42452,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100017.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 3, tzinfo=tzlocal()),
#   'ETag': '"a5093ed1b455790ede845fcc3cc745dc"',
#   'Size': 37648,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100018.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"f7c6196659eb96dafcf84a80436bd6d8"',
#   'Size': 41715,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100019.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"9de097ab8ccf30942bfb8976527d4073"',
#   'Size': 45949,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10002.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"afd7c2d751a8ee0443a2a9dd79fd01e2"',
#   'Size': 45103,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100020.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"a08256f32ad4b632c1e3f8e549b0a963"',
#   'Size': 38621,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100022.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"3a4ccb09ab8419cb3f0ff5eb37bb3c1b"',
#   'Size': 51351,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100023.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"d01c5f28693003e330ba7cd11bbfeb1c"',
#   'Size': 34786,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100024.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"449549f71309eef7e42bba611634b3cc"',
#   'Size': 38276,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100025.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"751fab1078b5ffca798e0bcb2215bda8"',
#   'Size': 49780,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100028.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"0c3a7a2a7e3b80463f0e87be8356b98e"',
#   'Size': 40368,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100030.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"c772500f505ff6050ad3d9b24aad01f1"',
#   'Size': 39052,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100031.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"8412a1a5ae373d0764e7fa65236c8abf"',
#   'Size': 46555,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100032.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"562cf1d492e2e8358e6484ba2b64cb77"',
#   'Size': 48793,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100033.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"c7ba677c6faef901dffc8e533277d39f"',
#   'Size': 48303,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100034.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"13b6ac5e138a4dc24827fa9ac5617a2b"',
#   'Size': 44328,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100035.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"68ae299cee0ce2bdbb5b5b01f767bdb3"',
#   'Size': 43410,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100037.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"ed4890920108a384b6f7939e5908be53"',
#   'Size': 40169,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100038.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"b8b8de6d9f0dba4ad9cdf5642e68110f"',
#   'Size': 42493,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100039.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"8707725527e0ed9b7793dbfc13267dfa"',
#   'Size': 36339,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10004.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"5548aeb245a629c53525a36cafca4b1f"',
#   'Size': 38169,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100040.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"83753ff91f715b01a65713c1a7012a3e"',
#   'Size': 40757,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100042.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"4e2fcf81bbd80bc5e34a4fd130561248"',
#   'Size': 45398,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100043.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"c1b1f0e98e460b969a71f8fd48ed10ab"',
#   'Size': 40040,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100044.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"d2f3b6d5a7e43667e6b87c9bfe0df737"',
#   'Size': 43317,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100047.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"b3b2380cc4f070dfc9b03262cc717202"',
#   'Size': 44700,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100049.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"bf86fa8a6f8e2b0dd5d19b9af59a49bc"',
#   'Size': 41481,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10005.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"76b02b18b3a1b6808f7525da278b68fa"',
#   'Size': 41892,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100051.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"59164a91ead19a97bc309140c24799b0"',
#   'Size': 41950,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100052.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"21a935aeb421f64226acbbfe85fb35fc"',
#   'Size': 39299,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100053.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"1e967bd098244cf276dfea1589a36721"',
#   'Size': 37623,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100054.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"3477c7eb95071ea2ee0ae19287bc6bcc"',
#   'Size': 36546,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100055.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"90dbd4b6cfcf63a1b6d193112a369231"',
#   'Size': 44248,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100056.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"0623deae62d335402695269d04fe44b5"',
#   'Size': 45102,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100058.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"6d7254b98dbf8ee5329d983b83ff795a"',
#   'Size': 40062,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100059.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"90b6b8f4a4b1a4bc5dc6339ca684b95a"',
#   'Size': 45702,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10006.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"2e1b43aed5a4653dae744bc6f004fb56"',
#   'Size': 49225,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100060.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"b3b25d64a70ac34e44e84e97a82c8aa1"',
#   'Size': 36731,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100062.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"d96c6c0193a53a11ff2dd8bd343faa96"',
#   'Size': 35991,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100063.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"698499f1ca2e7344abb71627cf9635d0"',
#   'Size': 37878,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100064.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"2992bc8077dd8f1e96809d2af2e9ebcf"',
#   'Size': 42513,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100066.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"3c4d8f9184d10b715e4abe843a91dfe1"',
#   'Size': 48894,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100067.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"0440dffb4bc94a9749b0d64f3ea80ac0"',
#   'Size': 40190,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100068.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"576b3749d2e4a6a87b22170e1c4f536a"',
#   'Size': 47828,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100069.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"074577997fa5981320a1e780ab4ac771"',
#   'Size': 48945,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10007.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"2066acd34db27cf977bbf24c5097fadb"',
#   'Size': 39613,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100070.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"c08f41e89491e5e66ddb681ee9e5a1a8"',
#   'Size': 40050,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100071.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"532bbc367699a9ff29f4f4f8bc83dedc"',
#   'Size': 40447,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100072.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"bdd6fe2ed8fa628d3e0a634ccf253ef8"',
#   'Size': 42252,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100073.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"763f3cf3559015df111f0e8bc6878288"',
#   'Size': 51606,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100075.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"a060440fd0e0cd561415bce2e55ec49a"',
#   'Size': 46742,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100077.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"9699cc3592e56f1cf0461b992e7136f1"',
#   'Size': 45285,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100078.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"cc44e871161532b5faefb44d1583e7ce"',
#   'Size': 37464,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100079.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"c42a5eb4a3195b1c699ebc642e66645b"',
#   'Size': 37311,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10008.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"bcf1044fdc08f3eed55d4e2396d2340f"',
#   'Size': 48791,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100080.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"e2f116a835f817240370f12c90a15745"',
#   'Size': 43635,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100081.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"4d42b0356c6760c7579835728205b914"',
#   'Size': 42393,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100082.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"dcd4e65bcc62f6796814563ef6eb869b"',
#   'Size': 45515,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100083.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"bc5ef56e88a42d7352f8fef5a776c732"',
#   'Size': 38254,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100084.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"113fa33842a82417b1ebb9800c70dc1f"',
#   'Size': 37922,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100085.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"ef027d0b0278e488b90054816ffbbc21"',
#   'Size': 34338,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100086.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"985d7679bcaea3252dfcd61d0cc3be11"',
#   'Size': 50338,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100087.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"ba86f14d0f5a64d6a8d149e6b9af1a68"',
#   'Size': 37747,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100088.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"f933bc19a015ae56528490450c9b250c"',
#   'Size': 46752,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100089.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"78c51e53017485b533fc9fb5d21137ac"',
#   'Size': 53368,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10009.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"dfa448e5a20d61bace841006424d9fc0"',
#   'Size': 42621,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100091.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"fe8084193380efd371660dd12f9978ac"',
#   'Size': 43295,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100092.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"0fc2f402c45fe00c25999856fc85a0d6"',
#   'Size': 37080,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100093.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"421dd7b30f716b9159a3293ce92890e9"',
#   'Size': 42918,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100094.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"47c8e4add8b45710c9fc963f1c0f67e3"',
#   'Size': 46932,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100095.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"70f83ad208b0f5eff6716c3a5e78d2fe"',
#   'Size': 47149,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100096.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"4d5db8afb46dcc65a2ab3f9b325abc00"',
#   'Size': 39450,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100097.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"a97aafa5dd570f67645facfbb634cc81"',
#   'Size': 49218,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100098.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"15d23c8cd6957faaaec00b8d524c70b6"',
#   'Size': 41975,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100099.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"27d4966e752fa48649a504cc430ac953"',
#   'Size': 38828,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_1001.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"cc443b58dbb1dc10f20dd08c5fa2411b"',
#   'Size': 43257,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10010.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"844d135533baa7915c3acd2dbd0d93b9"',
#   'Size': 43799,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100101.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"5ccaeb1635cc6db6d1e9c66f8ac929f5"',
#   'Size': 39568,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100102.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"74effc8dd76c0adf7b82b249e223e975"',
#   'Size': 44929,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100103.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"f567c223bcf750bf75ee086d3432fc44"',
#   'Size': 41968,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100104.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"8412d48223b701106a1711d7edb09b36"',
#   'Size': 54065,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100105.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"28762f52b8a5c87acebf5a1ad125cfb6"',
#   'Size': 44084,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100106.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"0fd50c37010581e5f2deeebce6e04e7b"',
#   'Size': 39698,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100107.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"7df64dd922bd41047ec893f06c31b751"',
#   'Size': 48495,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100110.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"6dbf18727607be86dbe11d5836016765"',
#   'Size': 37138,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100111.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"a4a549765fb3150c327fb3d6a3276ef2"',
#   'Size': 40797,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100112.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"11885f6f45b6f66fb686de7d81f7b911"',
#   'Size': 48863,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100114.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"3347197c9c25431c4499bbd3cea0dca9"',
#   'Size': 54518,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100115.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"f4deae2da9133473c4efc1430d25bbe1"',
#   'Size': 40230,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100117.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"e9857796a1eff49bccdc9158681a05e9"',
#   'Size': 42995,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100118.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"18885f7a3032e2a46908493194803f82"',
#   'Size': 36737,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100119.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"5deebc2dde260cd2311d31da460f1ad4"',
#   'Size': 43104,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100120.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"ad5b7440a7677aa5dfe50dc9c64dd043"',
#   'Size': 35806,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100122.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"5b2c3d5b7a71e2f330aa415f21f78014"',
#   'Size': 37184,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100123.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"449f88e57a4504d8f1edd7c43904b7d7"',
#   'Size': 36576,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100124.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"b6338b18821b7da1e6d2f659515293c7"',
#   'Size': 44215,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100125.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"5fbb73b7a612bd509c0c79456e0dc37e"',
#   'Size': 39366,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100127.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"d00159115a8668f8b7f1c86675488875"',
#   'Size': 45103,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100128.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 4, tzinfo=tzlocal()),
#   'ETag': '"a348dfedd85257279cab048d1c7c35bc"',
#   'Size': 51087,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100129.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"60c33eea2c2efa1729476fa7caef8d25"',
#   'Size': 42985,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10013.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"bd20562847600db80bdc1fa96f39fe86"',
#   'Size': 39097,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100130.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"e67b5f421b98d3786379af3ed2aff9b2"',
#   'Size': 42795,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100131.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"4bb2f80a211c18163bb1f6f4ce3b3da9"',
#   'Size': 41649,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100132.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"b1d550cbe40b9edca3557c5b586e77e0"',
#   'Size': 43896,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100133.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"7d38f6d7d577fcde4bd58a2749605596"',
#   'Size': 39696,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100134.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"a2370f79089543a7e4d4b1bff74dd6d1"',
#   'Size': 50188,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100137.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"3e4d4cc82e8096b97806dfe541f2b573"',
#   'Size': 41251,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100138.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"7294a686b0dab123e4cdf09c89f37450"',
#   'Size': 43660,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10014.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"d60736342570045583b0825f06bed0d9"',
#   'Size': 50513,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100140.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"5bfffe8d1366e9cb4040b2fa250d6d7b"',
#   'Size': 48421,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100141.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"c4b1009448047f0fa729ac3ca645f3ba"',
#   'Size': 42166,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100142.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"3b213d6ea109381f1e5a754345c4b676"',
#   'Size': 40376,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100143.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"318334e0d30280a055665f382a33496f"',
#   'Size': 38510,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100146.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"5a7b03559a9e45bd30de2cb5ba5d9faf"',
#   'Size': 43434,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100147.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"cb650289d79ca848b182e4fdc7f8fbe6"',
#   'Size': 42985,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100148.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"18ef5d20536608fb792c0a112ed099d6"',
#   'Size': 41861,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100149.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"03a75795d02723ab14fae5c9e980729a"',
#   'Size': 39909,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10015.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"3fd89c24161cd9e1bfe2715a4bc09187"',
#   'Size': 56418,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100150.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"063958211e94614464fcd4924d6b575a"',
#   'Size': 48040,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100151.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"9d90246a7b31faaca93735f010e6155b"',
#   'Size': 38613,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100154.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"daff2909bb47719d3d090cfa636c5310"',
#   'Size': 43446,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100156.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"8a94f0af7100d03a60956598a88a1cc5"',
#   'Size': 50565,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100157.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"335f42242dfb11e8477b52c907aa484a"',
#   'Size': 40308,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100158.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"d0f966b359e856d76f7a8119cfae581c"',
#   'Size': 45951,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100159.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"dd0ca1d82d5785e898bee909332d96c7"',
#   'Size': 37799,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10016.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"04f495806971a9e8ea3651c704893c05"',
#   'Size': 43295,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100160.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"e6ef52ce3d25fbadf7b1f16312bd7bb3"',
#   'Size': 43572,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100161.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"ff1a2c647261642679d182afe12406c9"',
#   'Size': 42839,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100162.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"1664785e2398520d887fe1aa20b600cb"',
#   'Size': 41235,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100163.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"9c9cf7846c9f62b63dbb46018611c207"',
#   'Size': 35147,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100165.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"ce9c549888b6e317d3dadbfe8c2c2e93"',
#   'Size': 51813,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100166.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"bcb418f213733130cc7aeac686600e7b"',
#   'Size': 43628,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100169.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"b888a46c23cff553ec826f8ca7cd41a3"',
#   'Size': 43412,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10017.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"75b048d5830e1ddf08b57265dcf622fc"',
#   'Size': 39340,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100170.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"592b40e7249c9a8831f1f8ec1b739137"',
#   'Size': 44538,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100171.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"286ca3d592f345032f99be686aee42b8"',
#   'Size': 37723,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100172.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"e18264d518309b25cf0cf60bef51cc55"',
#   'Size': 41413,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100173.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"8d6c2019599be981f869b5a010ca20f7"',
#   'Size': 41691,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100174.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"010df13ef3adbafa2046f369435e1ad2"',
#   'Size': 42498,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100175.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"cc52413d81f297e29373f24cc4e9119f"',
#   'Size': 45727,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100177.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"d467732f2da5d483ecff10a3ecf65dbe"',
#   'Size': 43675,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100178.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"46c1b1ab20e7028250034bc8a80062c2"',
#   'Size': 43641,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100179.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"fb028cda7c039fc5f62b11f684bd884d"',
#   'Size': 44622,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10018.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"db5a9fd11d40c0cb4ba1b726e58c07e7"',
#   'Size': 33173,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100180.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"88837b3e60688a92b3403c184f48662f"',
#   'Size': 38559,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100182.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"c3573b08604d1722e302a2505f654f4c"',
#   'Size': 56091,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100183.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"ca752a31d8546fedd4fac40dc09ea379"',
#   'Size': 45015,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100184.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"6c14ad80e66b103b3f1607453499283e"',
#   'Size': 43511,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100185.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"6c720229132433298e10f599ef778988"',
#   'Size': 37642,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100186.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"d095170f1f9c52565fbb8cb7669a0d87"',
#   'Size': 46979,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100187.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"4923f280c9cbca8a84717dc322b70cde"',
#   'Size': 39245,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100189.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"5f726ba831fcd74e64bdbb473e7c77e2"',
#   'Size': 38587,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10019.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"9e707027f86201e33a545851bed40874"',
#   'Size': 40481,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100192.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"2fe52582b9e3bc6e0bf5af8001d468cf"',
#   'Size': 43481,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100193.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"dc55e19a4c3c7bd019c5250d9ac6d426"',
#   'Size': 40339,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100194.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"3288205b863c6ce5c612730d6f8d44ac"',
#   'Size': 52448,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100195.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"54425f2f0809e48f87284880d8f481b8"',
#   'Size': 42584,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100196.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"241e6d627deabb56f46417eec6382bdc"',
#   'Size': 44127,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100197.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"d6a7812c7ae819f87f36310c8a1a0dba"',
#   'Size': 36855,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100198.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"86b38e70b877927d2bea0a9f120a2736"',
#   'Size': 41229,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100199.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"e6258ad408da22a1af8260591c218d7c"',
#   'Size': 42200,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_1002.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"9b3bdb3c29d32b2b6e79529a36233630"',
#   'Size': 36711,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10020.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"105d3ac236eaa5f8b461bd5cf48ed5f8"',
#   'Size': 44292,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100202.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"310a5111fcf750aeaf99cac29a2c6b3c"',
#   'Size': 42918,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100203.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"f3b2b4795b08586eb7209ce7c635fefb"',
#   'Size': 40064,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100204.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"613f48fbeb3d9652004919ef0e277af3"',
#   'Size': 46851,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100205.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"34b2d69368536b8ebe9ed6a1bc016a6b"',
#   'Size': 35597,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100206.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"56054d069f746b635ac623f007a8b69b"',
#   'Size': 38509,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100207.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"24a12151e961f044ba88782a60f9a9dc"',
#   'Size': 36139,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100208.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"9d90544e269cc74ed5124811ee763f75"',
#   'Size': 41150,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100209.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"72ccfcef45dab1a5b17371267641fae0"',
#   'Size': 45968,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10021.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"ad2ffec9157852c6d00f3685efdad2cb"',
#   'Size': 35863,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100210.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"9c26280457c6fcf7f07ffc23f757433f"',
#   'Size': 37558,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100211.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"9a1d0d4b20772a01c11f8e029156769c"',
#   'Size': 40729,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100212.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"786aa4bf769f80074f3cad230134acc1"',
#   'Size': 48270,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100213.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"5152f098e5c957cd14e4c18e57886b08"',
#   'Size': 39423,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100214.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"e11335767b50c60b5ddd835ea85b249e"',
#   'Size': 52168,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100216.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"ad5cfd10f59637ac9aad551e90484353"',
#   'Size': 42309,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100217.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"6b58ae7ad8d64cca03b5be6fa2cead6d"',
#   'Size': 42058,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100218.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"893214593dfbcf65e4f04cded808484e"',
#   'Size': 43206,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100219.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"9ee9c9cc5f358a94ad52e0eb731084ea"',
#   'Size': 48349,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10022.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"6020d5ba8c26793c64ee6a8210728bc5"',
#   'Size': 47510,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100220.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"1f7b4daeafd819534b2c7238937dc831"',
#   'Size': 38825,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100221.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"71f4025cc4f3ef640d129b35316e815c"',
#   'Size': 44511,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100222.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"97d1b8e8356e632ca740e7fd2905c8cb"',
#   'Size': 42569,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100223.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"be8e5da8504fff8361568f56b0120af5"',
#   'Size': 42979,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100224.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"6154debf530699cdeb313155613d7dab"',
#   'Size': 37718,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100226.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"af072fb799bbe7390cc46d682a10a32c"',
#   'Size': 37188,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100227.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"c9e1e0a8ff598a6818302b506506d5de"',
#   'Size': 42194,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100228.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"be17931adcf15928ef5d1d212a1e4d9a"',
#   'Size': 35873,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100229.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"15ecb842c9a142d6f1446ef25d91cba4"',
#   'Size': 47307,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10023.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"cb66bac1837b0c37bcd300abad03fc38"',
#   'Size': 43534,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100231.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"f35a3ea458c0e77c1ea7d890891dd68f"',
#   'Size': 46853,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100233.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"954218eb33121e107de0c3a1879d9430"',
#   'Size': 41920,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100234.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"82ccd6592f6ec2132e8ba496a1ffbe7c"',
#   'Size': 49387,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100236.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"8c8660db4df64884f1b157a5680c0f15"',
#   'Size': 40050,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100237.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 5, tzinfo=tzlocal()),
#   'ETag': '"df89ed3dc266a4037c8dccf632785211"',
#   'Size': 39903,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100238.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 6, tzinfo=tzlocal()),
#   'ETag': '"f342259c7cffedb4a08d12cee1032f75"',
#   'Size': 42992,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100239.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 6, tzinfo=tzlocal()),
#   'ETag': '"6703b4b70c0e00c0d906f0212655a4ef"',
#   'Size': 34352,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10024.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 6, tzinfo=tzlocal()),
#   'ETag': '"55441743cdeabf6298753a0dea0680a6"',
#   'Size': 47932,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100240.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 6, tzinfo=tzlocal()),
#   'ETag': '"1826a4bb9c79b14327f1e65a46ea4b87"',
#   'Size': 40568,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100243.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 6, tzinfo=tzlocal()),
#   'ETag': '"ca6d649ac0c30bcfe60a9611a65c8764"',
#   'Size': 45378,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100244.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 6, tzinfo=tzlocal()),
#   'ETag': '"3e5fa5d9c8ac50415e81af213ef9ab56"',
#   'Size': 37373,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100245.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 6, tzinfo=tzlocal()),
#   'ETag': '"021fbea59a023906271b330f1fc47a32"',
#   'Size': 39893,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100247.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 6, tzinfo=tzlocal()),
#   'ETag': '"9fdd054849e378e440db9b591c1da73f"',
#   'Size': 47225,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_100248.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 6, tzinfo=tzlocal()),
#   'ETag': '"d01688349ccd7033e5386ddddf0cbdf1"',
#   'Size': 42520,
# ...
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"c6f7fd60955b8587489d77fd1600fa4a"',
#   'Size': 41479,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10105.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"07e9e4f5aacc1fcaefdff9a63083e556"',
#   'Size': 37941,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101050.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"30db52edf47dd20efa0b356c52b44483"',
#   'Size': 38592,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101052.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"f1d7685ec4e089bc2eea65aa4530abaa"',
#   'Size': 47491,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101053.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"249abef0871f15184529d866b9632fea"',
#   'Size': 41546,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101054.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"2933247bfc4b0f4e40cd08d02071bd97"',
#   'Size': 43192,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101055.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"625dba087a9d62fd761677971c30ffe8"',
#   'Size': 49615,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101056.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"c26d5b696c43af88f524aab6df4130eb"',
#   'Size': 49298,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101057.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"84decd53238151a065224182c4ab5fc8"',
#   'Size': 43942,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101058.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"5644f6325ae9540d5a5b6ece0b850e68"',
#   'Size': 42695,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10106.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"4d03d106b99df0bbfd4e2095fc1a0edd"',
#   'Size': 39098,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101060.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"4727ba8aea3f9f6b761046006acbf880"',
#   'Size': 45403,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101061.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"a011aea36eaf27e8a52581c6de0dd330"',
#   'Size': 47053,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101062.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"01ff9d563dbff5270de051bb0ee9dd65"',
#   'Size': 45736,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101064.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"6cd3a5843c2d87e825a44d0af7f9d9a7"',
#   'Size': 43613,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101067.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"f21d5768f552a9d997bb61be07c3b4f4"',
#   'Size': 36199,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101069.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"67354fc79d35acc1f315c49d6299e9fc"',
#   'Size': 44793,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10107.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"d5150c056425b051de1d56993a7c0b83"',
#   'Size': 41580,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101070.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"6fd12cbc133e36293a80f6119d3f9f2b"',
#   'Size': 52074,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101071.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"388e16945a1c70287010d84d17a365e7"',
#   'Size': 40617,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101072.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"73a4f73a59af2a8f7edacc2824baee63"',
#   'Size': 44714,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101073.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"0f7c205e31cee5c14ef83d3dab13e4c6"',
#   'Size': 40252,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101074.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"fe6bb7fa637b7379464dfc8f07be4b43"',
#   'Size': 40697,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101076.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"2f0d5b2ce733f317e49b26d1607fea35"',
#   'Size': 40181,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101080.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"365cdb784e15cdef1cd6e5d12d3a41f2"',
#   'Size': 38448,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101081.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"84e2fb9dac68f5bd0ce7d43854bcb2c1"',
#   'Size': 43704,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101082.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"7a83e23b3fbeebe4fa09b71957c5558f"',
#   'Size': 52591,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101083.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"666bdef9e5de8b173c7bc51322a76321"',
#   'Size': 43413,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101084.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"1de4e606ddfe8b73ca4fcbb6e8237018"',
#   'Size': 42905,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101085.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"343ba9fe78a8cb4bf44eb4d86bffbc15"',
#   'Size': 51043,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101089.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"6a174ecdffd819888b57a8005913c547"',
#   'Size': 40226,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10109.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"d7edd0a8c6cceebfb14c1ea83a23ab0e"',
#   'Size': 40078,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101090.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"3b327ccc0023cfa7b6131bb98cf01022"',
#   'Size': 43091,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101092.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"ff7de129974076936d3404f8e7378590"',
#   'Size': 36551,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101094.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"3563118fbb629fa67e55879e4d181888"',
#   'Size': 44810,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101095.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"02762084a5b463b53d4a586703d8f0e0"',
#   'Size': 38296,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101098.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"27c57c0a0fd2e3070a81a80542e57276"',
#   'Size': 39359,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101099.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"d4ce8f31c2273cb90e742b3b68a8dca8"',
#   'Size': 36950,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_1011.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"7d465c5883db6bd5b4313407ad41f34d"',
#   'Size': 39514,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10110.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"1fd197f7e1e1a25c3820a260d6403351"',
#   'Size': 41764,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101100.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"726b41af144ad1cf36a3a59bc537cacd"',
#   'Size': 50865,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101101.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"d38b8210f15995efffa5ef244f4c6bec"',
#   'Size': 43777,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101103.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"a3253edadca1358a9ec7d2005265f27d"',
#   'Size': 42486,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101104.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"befcebb685a4aa76d72ca5b3e96a067c"',
#   'Size': 42271,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101105.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"d50e8754fa57723323874daaad91f2d0"',
#   'Size': 41784,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101106.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"c5b9139d050fb161b57ce771bf2f7883"',
#   'Size': 42416,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101108.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"fd6786007595458b3b31a2ee13ecf69b"',
#   'Size': 36691,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101109.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"6e969a49f39e6967eba8af26ccab2190"',
#   'Size': 50166,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10111.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 14, tzinfo=tzlocal()),
#   'ETag': '"c30b2f09f3471ff14840ce818e66e4df"',
#   'Size': 52331,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101111.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"78180c133211d583e694f646b43405dd"',
#   'Size': 42791,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101112.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 14, tzinfo=tzlocal()),
#   'ETag': '"4b57ef4eeecd0776a79a77d783d96e13"',
#   'Size': 48344,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101114.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 13, tzinfo=tzlocal()),
#   'ETag': '"f837188d9a0e392d9fe5f7a2e57a9165"',
#   'Size': 35805,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101115.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 14, tzinfo=tzlocal()),
#   'ETag': '"c10c9c34ebb7edba80423d85e90d6de3"',
#   'Size': 41328,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101116.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 14, tzinfo=tzlocal()),
#   'ETag': '"92d6032ecbffe95f8216968d18d81ee4"',
#   'Size': 39666,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101117.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 14, tzinfo=tzlocal()),
#   'ETag': '"de0d93e01da0218790eddc95a926c9e1"',
#   'Size': 39606,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101119.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 14, tzinfo=tzlocal()),
#   'ETag': '"3f7d544efa12f7a481ef60c083403088"',
#   'Size': 43172,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10112.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 14, tzinfo=tzlocal()),
#   'ETag': '"28472ac11b19c87c2d758c008320c376"',
#   'Size': 42580,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101120.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 14, tzinfo=tzlocal()),
#   'ETag': '"219185da53a9f045bb5028e5e10a36f7"',
#   'Size': 45552,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101121.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 14, tzinfo=tzlocal()),
#   'ETag': '"cba6199e21c8e20a01504df19e828172"',
#   'Size': 35593,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101124.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 14, tzinfo=tzlocal()),
#   'ETag': '"e7ff04d228f37750737d8fd76916a5d6"',
#   'Size': 39999,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101125.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 14, tzinfo=tzlocal()),
#   'ETag': '"46b08f6da2e26b2c13c580da638624be"',
#   'Size': 39129,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101126.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 14, tzinfo=tzlocal()),
#   'ETag': '"7a0fd08c7eb26dce323f51b6110e29c8"',
#   'Size': 40548,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101127.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 14, tzinfo=tzlocal()),
#   'ETag': '"280ae5160721859f0de9ab4a3a30b1b8"',
#   'Size': 41161,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101128.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 14, tzinfo=tzlocal()),
#   'ETag': '"74bcba0a6a39f0703c10542c7bfde839"',
#   'Size': 38258,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101129.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 14, tzinfo=tzlocal()),
#   'ETag': '"4cfd4709388e460160dcd44a8cfe6c87"',
#   'Size': 41868,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10113.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 14, tzinfo=tzlocal()),
#   'ETag': '"f2b6377de9f70588ba767d36e638af88"',
#   'Size': 37816,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101131.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 14, tzinfo=tzlocal()),
#   'ETag': '"106226af1b379e043505f591a0be2403"',
#   'Size': 45943,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101132.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 14, tzinfo=tzlocal()),
#   'ETag': '"a0ed058c9e0584d72b901f3e8bfeca32"',
#   'Size': 44545,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101133.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 14, tzinfo=tzlocal()),
#   'ETag': '"a743bd27f12916be8a8366affa945ce2"',
#   'Size': 43868,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101135.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 14, tzinfo=tzlocal()),
#   'ETag': '"9188a305bd7557f148f67fd99a6634f9"',
#   'Size': 52467,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101137.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 14, tzinfo=tzlocal()),
#   'ETag': '"cd27e26ec944463fb15ddf3cc8c88cb4"',
#   'Size': 39492,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101138.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 14, tzinfo=tzlocal()),
#   'ETag': '"08edda42e3f2106711d7fec869d659ca"',
#   'Size': 46981,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101139.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 14, tzinfo=tzlocal()),
#   'ETag': '"774e3058a3250d659db3f8e5cfd2c531"',
#   'Size': 45557,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_10114.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 14, tzinfo=tzlocal()),
#   'ETag': '"747c089063f2291c866685f055225666"',
#   'Size': 37393,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101140.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 14, tzinfo=tzlocal()),
#   'ETag': '"30feed3e79895cb4119115db0044165c"',
#   'Size': 45300,
#   'StorageClass': 'STANDARD'},
#  {'Key': 'imgs/test/img_101141.jpg',
#   'LastModified': datetime.datetime(2020, 3, 2, 2, 39, 14, tzinfo=tzlocal()),
#   'ETag': '"2b62a11de82be8445ffd62ce69043596"',
#   'Size': 45157,
#   'StorageClass': 'STANDARD'}]

# %%
'''
obj_list=s3_client.list_objects(Bucket=data_bucket_name)
file=[]
for contents in obj_list['Contents']:
    file.append(contents['Key'])
#print(file)
file_data=file[2]
'''

# %%
'''
file_data
'''
# Out:
#   File "<ipython-input-33-3090a6019626>", line 2
#     '''
#        ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %% [markdown]
# Import the data into the variable **response_body** then read into a dataframe.

# %%
'''
response = s3_client.get_object(Bucket=data_bucket_name, Key=file_data)
print(list(response))
response_body = response['Body'].read()
df_wine_red = pd.read_csv(io.BytesIO(response_body), header=0, delimiter=";", low_memory=False) 
'''
# Out:
# ['ResponseMetadata', 'AcceptRanges', 'LastModified', 'ContentLength', 'ETag', 'ContentType', 'Metadata', 'Body']

# %% [markdown]
# # Preprocessing

# %% [markdown]
# We need to define input file as a string to the S3 bucket location for the SKLearn process to be able to call.

# %%
# Input File Path Check
input_data = 's3://dsba-6190-final-team-project/data/winequality-red.csv'.format(region)

# %% [markdown]
# ## Preprocessing

# %%
#Initialize SKLearn Preprocessing Function
sklearn_processor = SKLearnProcessor(framework_version='0.20.0',
                                     role=role, 
                                     base_job_name = "scikit-preprocessing",
                                     instance_type='ml.m4.xlarge',
                                     instance_count=1)

# %% [markdown]
# ### Preprocessing Script
# The following script is used to run the preproocessing stage.

# %%
# %%writefile preprocessing.py

import argparse
import os
import warnings

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.exceptions import DataConversionWarning
warnings.filterwarnings(action='ignore', category=DataConversionWarning)

seed = 5590

if __name__=='__main__':
    parser = argparse.ArgumentParser()
    parser.add_argument('--train-test-split-ratio', type=float, default=0.2)
    args, _ = parser.parse_known_args()
    
    print('Received arguments {}'.format(args))
    
    input_data_path = os.path.join('/opt/ml/processing/input', 'winequality-red.csv')
    
    print('Reading input data from {}'.format(input_data_path))
    df = pd.read_csv(input_data_path, header=0, delimiter=";", low_memory=False)
    
      
    split_ratio = args.train_test_split_ratio
    
    print('Splitting data into train and test sets with ratio {}'.format(split_ratio))
    
    #Split Data into training / test
    X_train, X_test, y_train, y_test = train_test_split(df.drop('quality', axis=1), 
                                                        df['quality'], 
                                                        test_size=split_ratio, 
                                                        random_state=seed)
    
    # Transform Features
    scaler = StandardScaler().fit(X_train)
    train_features = scaler.transform(X_train)
    test_features = scaler.transform(X_test)
    
    # Convert Data to Float32
    train_features = train_features.astype('float32')
    test_features = test_features.astype('float32')
    
    # Create local output directories
    try:
        os.makedirs('/opt/ml/processing/output/train')
        os.makedirs('/opt/ml/processing/output/test')
    except:
        pass
    
    print('Train Features shape after preprocessing: {}'.format(train_features.shape))
    print('Train Labels shape after preprocessing: {}'.format(y_train.shape))
    print('Test Features shape after preprocessing: {}'.format(test_features.shape))
    print('Test Labels shape after preprocessing: {}'.format(y_test.shape))
    
    train_features_output_path = os.path.join('/opt/ml/processing/output/train', 'train_features.csv')
    train_labels_output_path = os.path.join('/opt/ml/processing/output/train', 'train_labels.csv')
    
    test_features_output_path = os.path.join('/opt/ml/processing/output/test', 'test_features.csv')
    test_labels_output_path = os.path.join('/opt/ml/processing/output/test', 'test_labels.csv')
    
    print('Saving training features to {}'.format(train_features_output_path))
    pd.DataFrame(train_features).to_csv(train_features_output_path, header= False, index=False)
    
    print('Saving test features to {}'.format(test_features_output_path))
    pd.DataFrame(test_features).to_csv(test_features_output_path, header=False, index=False)
    
    print('Saving training labels to {}'.format(train_labels_output_path))
    y_train.to_csv(train_labels_output_path, header=False, index=False)
    
    print('Saving test labels to {}'.format(test_labels_output_path))
    y_test.to_csv(test_labels_output_path, header=False, index=False)
# Out:
# Writing preprocessing.py

# %% [markdown]
# The preprocessing script can now be run with the SKLearnProcessor.run() method.

# %%
hyperparameters = {
    'train-test-split-ratio': 0.25
}

# %%
hyperparameters
# Out:
# {'train-test-split-ratio': 0.25}

# %%
sklearn_processor.run(code='preprocessing.py',
                      arguments=['--train-test-split-ratio', '0.3'],
                      inputs=[ProcessingInput(
                        source=input_data,
                        destination='/opt/ml/processing/input')],
                      outputs=[ProcessingOutput(output_name='train_data',
                                                source='/opt/ml/processing/output/train'),
                               ProcessingOutput(output_name='test_data',
                                                source='/opt/ml/processing/output/test')]
                     )

preprocessing_job_description = sklearn_processor.jobs[-1].describe()

output_config = preprocessing_job_description['ProcessingOutputConfig']
for output in output_config['Outputs']:
    if output['OutputName'] == 'train_data':
        preprocessed_training_data = output['S3Output']['S3Uri']
    if output['OutputName'] == 'test_data':
        preprocessed_test_data = output['S3Output']['S3Uri']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-2c3db385bdb2> in <module>()
#       8                                                 source='/opt/ml/processing/output/train'),
#       9                                ProcessingOutput(output_name='test_data',
# ---> 10                                                 source='/opt/ml/processing/output/test')]
#      11                      )
#      12
#
# TypeError: run() got an unexpected keyword argument 'base_job_name'

# %% [markdown]
# ### Check Preprocessing Outputs

# %%
#output_config

# %% [markdown]
# Check to see that the training features were processed.

# %%
'''
training_features = pd.read_csv(preprocessed_training_data + '/train_features.csv', nrows=5,  header=None)
print('Training features shape: {}'.format(training_features.shape))
training_features
'''
# Out:
# "\ntraining_features = pd.read_csv(preprocessed_training_data + '/train_features.csv', nrows=5,  header=None)\nprint('Training features shape: {}'.format(training_features.shape))\ntraining_features\n"

# %%
'''
training_labels = pd.read_csv(preprocessed_training_data + '/train_labels.csv', nrows=5,  header=None)
print('Training labels shape: {}'.format(training_labels.shape))
training_labels
'''
# Out:
# Training labels shape: (5, 1)
#    0
# 0  7
# 1  5
# 2  5
# 3  6
# 4  7

# %%
'''
X_train = pd.read_csv(preprocessed_training_data + '/train_features.csv', header=None)

#Checks are for previous inconsistencies in data shape
print('The Training Data Features Dataframe has the following shape: {}'.format(X_train.shape))
print('The Training Data Features Numpy Array has the following shape: {}'.format(np.array(X_train).shape))

X_train.head(5)
'''
# Out:
# "\nX_train = pd.read_csv(preprocessed_training_data + '/train_features.csv', header=None)\n\n#Checks are for previous inconsistencies in data shape\nprint('The Training Data Features Dataframe has the following shape: {}'.format(X_train.shape))\nprint('The Training Data Features Numpy Array has the following shape: {}'.format(np.array(X_train).shape))\n\nX_train.head(5)\n"

# %%
'''
y_train = pd.read_csv(preprocessed_training_data + '/train_labels.csv', header=None)

#Checks are for previous inconsistencies in data shape
print('The Training Data Labels Dataframe has the following shape: {}'.format(y_train.shape))
print('The Training Data Labels Numpy Array has the following shape: {}'.format(np.array(y_train).ravel().shape))

y_train.head(5)
'''
# Out:
# The Training Data Labels Dataframe has the following shape: (1119, 1)
# The Training Data Labels Numpy Array has the following shape: (1119,)
#    0
# 0  7
# 1  5
# 2  5
# 3  6
# 4  7

# %% [markdown]
# ## Training

# %% [markdown]
# ### Training Script

# %%
# %%writefile train.py

import argparse
import os

import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestRegressor
from sklearn.externals import joblib

from sklearn.model_selection import cross_val_score

seed = 5590

# Inference Function
def model_fn(model_dir):
    clf = joblib.load(os.path.join(model_dir, "model.joblib"))
    return clf

if __name__=="__main__":
    
    print('Extracting Arguments')
    parser = argparse.ArgumentParser()
    
    # Hyperparameters
    parser.add_argument('--n-estimators', type=int, default=750)
    parser.add_argument('--max-features', type=str, default='sqrt')
    
    # Directories
    parser.add_argument('--model-dir', type=str, default=os.environ['SM_MODEL_DIR'])
    parser.add_argument('--train', type=str, default=os.environ['SM_CHANNEL_TRAIN'])
    parser.add_argument('--test', type=str, default=os.environ['SM_CHANNEL_TEST'])
    parser.add_argument('--train_file_features', type=str, default = 'train_features.csv')
    parser.add_argument('--train_file_labels', type=str, default = 'train_labels.csv')
    parser.add_argument('--test_file_features', type=str, default = 'test_features.csv')
    parser.add_argument('--test_file_labels', type=str, default = 'test_labels.csv')
    
    args = parser.parse_args()
    
    # Data Paths
    train_features_data = os.path.join(args.train, args.train_file_features)
    train_labels_data = os.path.join(args.train, args.train_file_labels)
    
    #test_features_data = os.path.join(args.test, args.test_file_features)
    #test_labels_data = os.path.join(args.test, args.test_file_labels)
    
    
    print('Reading input data')
    # Import Data
    ## Training
    X_train = pd.read_csv(train_features_data)
    y_train = pd.read_csv(train_labels_data)
    
    ## Test
    #X_test = pd.read_csv(test_features_data)
    #y_test = pd.read_csv(test_labels_data)
    
    # Convert Data to NP Array
    ## Training
    X_train = np.array(X_train)
    y_train = np.array(y_train).ravel()
    
    ## Test
    #X_test = np.array(X_test)
    #y_test = np.array(y_test).ravel()
    
    # Check Data Shape
    print(X_train.shape)
    print(y_train.shape)
    
    # Initialize Random Forest Regressor Model. 
    # Hyperparameters based on earlier local analysis
        
    model = RandomForestRegressor(n_estimators = args.n_estimators,
                                  max_features = args.max_features,
                                  random_state = seed)
    
    print('Training Random Forest Regression model')
    model.fit(X_train, y_train)
    
    print('Training Complete')
    
    # Metrics
    
    mse_neg = cross_val_score(model, X_train, y_train, scoring = 'neg_mean_squared_error', cv=10)
    mse_abs = np.absolute(mse_neg)
    rsme = np.sqrt(mse_abs)
    rsme_avg = np.mean(rsme)
    print('RMSE: {}'.format(rsme_avg))
    
    model_output_directory = os.path.join(args.model_dir, "model.joblib")
    print('Saving model to {}'.format(model_output_directory))
    joblib.dump(model, model_output_directory)
# Out:
# Overwriting train.py

# %% [markdown]
# ### Create SKLearn Estimator For Training

# %%
sklearn_est = SKLearn(
    entry_point='train.py',
    role=role,
    train_instance_count=1,
    train_instance_type="ml.c5.xlarge",
    framework_version='0.20.0',
    base_job_name='red-wine-rf-scikit-training',
    metric_definitions=[
        {'Name': 'RSME',
        'Regex': "RSME: ([0-9.]+).*$"}],
    hyperparameters = {'n-estimators': 500}
)

# %% [markdown]
# ### Fit SKLearn Esitmator to Training Data

# %%
sklearn_est.fit(
    {
        'train': preprocessed_training_data, 
        'test': preprocessed_test_data
    },
    wait = False
)

# %% [markdown]
# ### Training Job Output Information

# %%
training_job_description = sklearn_est.jobs[-1].describe()

model_data_s3_uri = '{}{}/{}'.format(
    training_job_description['OutputDataConfig']['S3OutputPath'],
    training_job_description['TrainingJobName'],
    'output/model.tar.gz')

# %% [markdown]
# ## Hyperparameter Tuning Test

# %%
'''
seed = 5590

# Define exploration boundaries
hyperparameter_ranges = {
    'n-estimators': IntegerParameter(10, 1000),
    'max-features': CategoricalParameter(['auto', 'sqrt', 'log2'])}

# create Optimizer
Optimizer = sagemaker.tuner.HyperparameterTuner(
    estimator=sklearn_est,
    hyperparameter_ranges=hyperparameter_ranges,
    base_tuning_job_name='red-wine-rf-hpo',
    objective_type='Minimize',
    objective_metric_name='RMSE',
    metric_definitions=[
        {'Name': 'RMSE',
        'Regex': "RMSE: ([0-9.]+).*$"}],
    max_jobs=15,
    max_parallel_jobs=3)
'''

# %%
'''
Optimizer.fit(
    {
        'train': preprocessed_training_data, 
        'test': preprocessed_test_data
    },
    wait = False
)
'''

# %%
'''
tuner = Optimizer.analytics()
df_tune_ouput_all = tuner.dataframe()

df = df_tune_ouput_all[df_tune_ouput_all['FinalObjectiveValue'] > -float('inf')]

df
'''
# Out:
#     FinalObjectiveValue  TrainingElapsedTimeSeconds           TrainingEndTime  \
# 0              0.598190                        55.0 2020-02-29 17:50:30+00:00
# 1              0.600965                        41.0 2020-02-29 17:48:52+00:00
# 2              0.608505                        54.0 2020-02-29 17:49:45+00:00
# 3              0.597289                        84.0 2020-02-29 17:47:40+00:00
# 4              0.597413                        70.0 2020-02-29 17:45:54+00:00
# 5              0.597129                        80.0 2020-02-29 17:45:58+00:00
# 6              0.597207                        90.0 2020-02-29 17:43:14+00:00
# 7              0.597364                        63.0 2020-02-29 17:42:16+00:00
# 8              0.597138                        68.0 2020-02-29 17:42:42+00:00
# 9              0.596790                        52.0 2020-02-29 17:38:45+00:00
# 10             0.601505                        89.0 2020-02-29 17:39:10+00:00
# 11             0.601010                        79.0 2020-02-29 17:38:50+00:00
# 12             0.596056                        56.0 2020-02-29 17:35:42+00:00
# 13             0.607877                        48.0 2020-02-29 17:35:08+00:00
# 14             0.598435                        53.0 2020-02-29 17:35:45+00:00
#
#                              TrainingJobName TrainingJobStatus  \
# 0   red-wine-rf-hpo-200229-1732-015-60904f48         Completed
# 1   red-wine-rf-hpo-200229-1732-014-c78d88a4         Completed
# 2   red-wine-rf-hpo-200229-1732-013-3a0ecf82         Completed
# 3   red-wine-rf-hpo-200229-1732-012-00dbcba5         Completed
# 4   red-wine-rf-hpo-200229-1732-011-1fcf2b15         Completed
# 5   red-wine-rf-hpo-200229-1732-010-3eab2de1         Completed
# 6   red-wine-rf-hpo-200229-1732-009-c1f213f3         Completed
# 7   red-wine-rf-hpo-200229-1732-008-ac409c29         Completed
# 8   red-wine-rf-hpo-200229-1732-007-f82de863         Completed
# 9   red-wine-rf-hpo-200229-1732-006-46f3de97         Completed
# 10  red-wine-rf-hpo-200229-1732-005-14a5bc5c         Completed
# 11  red-wine-rf-hpo-200229-1732-004-c504adab         Completed
# 12  red-wine-rf-hpo-200229-1732-003-c5d45414         Completed
# 13  red-wine-rf-hpo-200229-1732-002-ffb414ed         Completed
# 14  red-wine-rf-hpo-200229-1732-001-bd9e92dc         Completed
#
#            TrainingStartTime max-features  n-estimators
# 0  2020-02-29 17:49:35+00:00       "log2"         153.0
# 1  2020-02-29 17:48:11+00:00       "log2"          89.0
# 2  2020-02-29 17:48:51+00:00       "log2"          28.0
# 3  2020-02-29 17:46:16+00:00       "sqrt"         665.0
# 4  2020-02-29 17:44:44+00:00       "log2"        1000.0
# 5  2020-02-29 17:44:38+00:00       "log2"         706.0
# 6  2020-02-29 17:41:44+00:00       "log2"         919.0
# 7  2020-02-29 17:41:13+00:00       "sqrt"         259.0
# 8  2020-02-29 17:41:34+00:00       "sqrt"         704.0
# 9  2020-02-29 17:37:53+00:00       "log2"         302.0
# 10 2020-02-29 17:37:41+00:00       "auto"         762.0
# 11 2020-02-29 17:37:31+00:00       "auto"         448.0
# 12 2020-02-29 17:34:46+00:00       "sqrt"         349.0
# 13 2020-02-29 17:34:20+00:00       "sqrt"          29.0
# 14 2020-02-29 17:34:52+00:00       "sqrt"         142.0

# %% [markdown]
# # Deploy Model

# %%
sklearn_est.latest_training_job.wait(logs='None')
# Out:
# 2020-02-29 15:06:27 Starting - Preparing the instances for training
# 2020-02-29 15:06:27 Downloading - Downloading input data
# 2020-02-29 15:06:27 Training - Training image download completed. Training in progress.
# 2020-02-29 15:06:27 Uploading - Uploading generated training model
# 2020-02-29 15:06:27 Completed - Training job completed

# %%
artifact = sm_boto3.describe_training_job(
    TrainingJobName=sklearn_est.latest_training_job.name)['ModelArtifacts']['S3ModelArtifacts']

print('Model artifact persisted at ' + artifact)
# Out:
# Model artifact persisted at s3://sagemaker-us-east-1-726963482731/red-wine-rf-scikit-training-2020-02-29-15-03-44-768/output/model.tar.gz

# %%
sklearn_predictor = sklearn_est.deploy(initial_instance_count=1, 
                                   instance_type='ml.m4.xlarge')
# Out:
# ---------------!

# %% [markdown]
# # Shut Down Endopoint

# %%
'''
sagemaker.Session().delete_endpoint(sklearn_predictor.endpoint)
'''
